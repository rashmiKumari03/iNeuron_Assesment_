# %% [markdown]
# Question: 1
#
# Given the following tables:
#
# ![sql1.png](attachment:9fda1230-a78a-42a3-9e30-c09c82e1c45c.png)
#
# What will be the result of the query below?
#
# SELECT * FROM runners WHERE id NOT IN (SELECT winner_id FROM races)
#
# Explain your answer and also provide an alternative version of this query that will avoid the issue that it exposes.

# %% [markdown]
# ans :
#
# SELECT * FROM runners WHERE id NOT IN (SELECT winner_id FROM races)

# %% [markdown]
# Ans :
# Since select winner_id from races : the out put of this subquesy is 2,3,null .
# Now using this (2,3,null) data...we will find all the records which are there in runners having winner_id other than 2,3,null.

# %% [markdown]
# ![sql_1_ans.png](attachment:daef843b-d5e0-441d-9087-aa39f50eb165.png)

# %% [markdown]
# Question: 2
#
#
# Given two tables created as follows

# %% [markdown]
# ![sql2.png](attachment:ec24fd14-cbd7-4015-a080-1da0660fff66.png)

# %% [markdown]
# Write a query to fetch values in table test_a that are and not in test_b without using the NOT keyword.

# %% [markdown]
# Ans:

# %% [raw]
# select * from test_a as ta
# left join test_b as tb
# on ta.id = tb.id;

# %% [markdown]
# Question: 3
#
# Given the following tables:

# %% [markdown]
# ![sql3.png](attachment:0ec3ee0b-8272-49cc-9403-3cfb9750c361.png)

# %% [markdown]
# Write a query to to get the list of users who took the a training lesson more than once in the same day, grouped by user and training lesson, each ordered from the most recent lesson date to oldest date.

# %% [raw]
# SELECT u.user_id,count(*) AS count
# FROM users u
# JOIN training_details td ON td.user_id = u.user_id
# GROUP BY u.user_id, training_id,training_date
# HAVING count(*) > 1
# ORDER BY training_date DESC;

# %% [markdown]
# Question: 4
#
# Consider the Employee table below.

# %% [markdown]
# ![sql4.png](attachment:6afda391-34ee-4b48-a7a8-c62bfbe06708.png)

# %% [raw]
# select
#     e1.manager_id,
#     e2.manager,
#     AVG(e1.salary) AS average_salary_under_manager,
#     e1.Emp_id,
#     e1.Emp_name,
#     e1.salary AS employee_salary
# from employees e1
# join employees e2
# on e1.manager_id = e2.manager_id
# where e1.Emp_id IN (16, 17, 18)
# group by e1.manager_id;
